# %% [markdown]
# # Pandas Advanced — Ejercicios (Vinos)
#
# Trabaja con el archivo CSV de vinos que encontrarás en la carpeta `data`.
#
# ---
#
# 1. **Carga de datos**
#    - Lee el archivo CSV de los vinos.
#
#
# 2. **Análisis inicial**
#    - ¿Hay valores nulos dentro del DataFrame?
#    - ¿Qué columnas contiene?
#    - ¿Se te ocurre alguna columna que podamos elegir como índice para facilitar las búsquedas? ¿Quizás varias como un multiindex?
#      *Justifica tu elección.*
#
#
# 3. **Conversión de moneda**
#    - El precio viene en dólares.
#      Genera una columna nueva con el **precio en euros** (elige el factor de conversión).
#
#
# 4. **Normalización de columnas**
#    - Genera dos nuevas columnas:
#      - `body_score` (nota del 1 al 10)
#      - `acidity_score` (nota del 1 al 10)
#    - Elimina las columnas originales de body y acidity.
#
#
# 5. **Filtrado y búsquedas**
#    - Localiza los vinos de **Málaga**.
#
#
# 6. **Calidad-precio**
#    - Crea una columna que sea el **precio dividido por el rating** del vino.
#
#
# 7. **Reemplazo de caracteres**
#    - Reemplaza la letra `n` por la letra `ñ` en la columna `Country`.
#      ¿Crees que es necesario hacerlo en alguna otra columna? Razona tu respuesta.
#
#
# 8. **Reemplazo de valores de texto**
#    - Reemplaza `Red` por `Tinto` en todo el DataFrame.
#    - Ahora localiza los vinos tintos dentro del DataFrame.
#
#
# 9. **Detección de columnas redundantes**
#    - ¿Crees que hay columnas redundantes en el DataFrame? Si es así, indícalas.
#
#
# 10. **Clasificación simple**
#     - Genera una columna que sea `True` cuando un vino tenga **más de un 4,5 de rating**, y `False` en caso contrario.
#
# ---

# %% [markdown]
# ##1. **Carga de datos**
#    - Lee el archivo CSV de los vinos.

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np
# Out:
# Mounted at /content/drive

# %%
df_wine=pd.read_csv('/content/drive/MyDrive/data/wines_SPA.csv')
df_wine.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %% [markdown]
# ## 2. **Análisis inicial**
#
#   * ¿Hay valores nulos dentro del DataFrame?
#   * ¿Qué columnas contiene?
#   * ¿Se te ocurre alguna columna que podamos elegir como índice para facilitar las búsquedas? ¿Quizás varias como un multiindex? Justifica tu elección

# %%
df_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7500 non-null   object
#  1   wine         7500 non-null   object
#  2   year         7498 non-null   object
#  3   rating       7500 non-null   float64
#  4   num_reviews  7500 non-null   int64
#  5   country      7500 non-null   object
#  6   region       7500 non-null   object
#  7   price        7500 non-null   float64
#  8   type         6955 non-null   object
#  9   body         6331 non-null   float64
#  10  acidity      6331 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 644.7+ KB

# %%
df_wine.isnull().sum()
# Out:
# winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# country           0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64

# %%
df_wine.columns
# Out:
# Index(['winery', 'wine', 'year', 'rating', 'num_reviews', 'country', 'region',
#        'price', 'type', 'body', 'acidity'],
#       dtype='object')

# %%
df_winery=df_wine.set_index(['winery', 'wine'])
df_winery
# Out:
#                                       year  rating  num_reviews country  \
# winery               wine
# Teso La Monja        Tinto            2013     4.9           58  Espana
# Artadi               Vina El Pison    2018     4.9           31  Espana
# Vega Sicilia         Unico            2009     4.8         1793  Espana
#                      Unico            1999     4.8         1705  Espana
#                      Unico            1996     4.8         1309  Espana
# ...                                    ...     ...          ...     ...
# Contino              Reserva          2016     4.2          392  Espana
# Conreria d'Scala Dei Les Brugueres    2018     4.2          390  Espana
# Mustiguillo          Finca Terrerazo  2017     4.2          390  Espana
# Matarromera          Gran Reserva     2011     4.2          389  Espana
# Sei Solo             Preludio         2016     4.2          388  Espana
#
#                                                 region   price  \
# winery               wine
# Teso La Monja        Tinto                        Toro  995.00
# Artadi               Vina El Pison      Vino de Espana  313.50
# Vega Sicilia         Unico            Ribera del Duero  324.95
#                      Unico            Ribera del Duero  692.96
#                      Unico            Ribera del Duero  778.06
# ...                                                ...     ...
# Contino              Reserva                     Rioja   19.98
# Conreria d'Scala Dei Les Brugueres            Priorato   16.76
# Mustiguillo          Finca Terrerazo      El Terrerazo   24.45
# Matarromera          Gran Reserva     Ribera del Duero   64.50
# Sei Solo             Preludio         Ribera del Duero   31.63
#
#                                                       type  body  acidity
# winery               wine
# Teso La Monja        Tinto                        Toro Red   5.0      3.0
# Artadi               Vina El Pison             Tempranillo   4.0      2.0
# Vega Sicilia         Unico            Ribera Del Duero Red   5.0      3.0
#                      Unico            Ribera Del Duero Red   5.0      3.0
#                      Unico            Ribera Del Duero Red   5.0      3.0
# ...                                                    ...   ...      ...
# Contino              Reserva                     Rioja Red   4.0      3.0
# Conreria d'Scala Dei Les Brugueres             Priorat Red   4.0      3.0
# Mustiguillo          Finca Terrerazo                   Red   4.0      3.0
# Matarromera          Gran Reserva     Ribera Del Duero Red   5.0      3.0
# Sei Solo             Preludio         Ribera Del Duero Red   5.0      3.0
#
# [7500 rows x 9 columns]

# %% [markdown]
# ## 3. **Conversión de moneda**
# * El precio viene en dólares.
# * Genera una columna nueva con el precio en euros (elige el factor de conversión).

# %%
EUR = 0.86
df_winery['price euro']=df_winery['price']*EUR
df_winery
# Out:
#                                       year  rating  num_reviews country  \
# winery               wine
# Teso La Monja        Tinto            2013     4.9           58  Espana
# Artadi               Vina El Pison    2018     4.9           31  Espana
# Vega Sicilia         Unico            2009     4.8         1793  Espana
#                      Unico            1999     4.8         1705  Espana
#                      Unico            1996     4.8         1309  Espana
# ...                                    ...     ...          ...     ...
# Contino              Reserva          2016     4.2          392  Espana
# Conreria d'Scala Dei Les Brugueres    2018     4.2          390  Espana
# Mustiguillo          Finca Terrerazo  2017     4.2          390  Espana
# Matarromera          Gran Reserva     2011     4.2          389  Espana
# Sei Solo             Preludio         2016     4.2          388  Espana
#
#                                                 region   price  \
# winery               wine
# Teso La Monja        Tinto                        Toro  995.00
# Artadi               Vina El Pison      Vino de Espana  313.50
# Vega Sicilia         Unico            Ribera del Duero  324.95
#                      Unico            Ribera del Duero  692.96
#                      Unico            Ribera del Duero  778.06
# ...                                                ...     ...
# Contino              Reserva                     Rioja   19.98
# Conreria d'Scala Dei Les Brugueres            Priorato   16.76
# Mustiguillo          Finca Terrerazo      El Terrerazo   24.45
# Matarromera          Gran Reserva     Ribera del Duero   64.50
# Sei Solo             Preludio         Ribera del Duero   31.63
#
#                                                       type  body  acidity  \
# winery               wine
# Teso La Monja        Tinto                        Toro Red   5.0      3.0
# Artadi               Vina El Pison             Tempranillo   4.0      2.0
# Vega Sicilia         Unico            Ribera Del Duero Red   5.0      3.0
#                      Unico            Ribera Del Duero Red   5.0      3.0
#                      Unico            Ribera Del Duero Red   5.0      3.0
# ...                                                    ...   ...      ...
# Contino              Reserva                     Rioja Red   4.0      3.0
# Conreria d'Scala Dei Les Brugueres             Priorat Red   4.0      3.0
# Mustiguillo          Finca Terrerazo                   Red   4.0      3.0
# Matarromera          Gran Reserva     Ribera Del Duero Red   5.0      3.0
# Sei Solo             Preludio         Ribera Del Duero Red   5.0      3.0
#
#                                       price euro
# winery               wine
# Teso La Monja        Tinto              855.7000
# Artadi               Vina El Pison      269.6100
# Vega Sicilia         Unico              279.4570
#                      Unico              595.9456
#                      Unico              669.1316
# ...                                          ...
# Contino              Reserva             17.1828
# Conreria d'Scala Dei Les Brugueres       14.4136
# Mustiguillo          Finca Terrerazo     21.0270
# Matarromera          Gran Reserva        55.4700
# Sei Solo             Preludio            27.2018
#
# [7500 rows x 10 columns]

# %% [markdown]
# ## 4. **Normalización de columnas**
# * Genera dos nuevas columnas:
#   * body_score (nota del 1 al 10)
#   * acidity_score (nota del 1 al 10)
# * Elimina las columnas originales de body y acidity.

# %%
min_body=df_wine['body'].min()
max_body=df_wine['body'].max()
min_acidity=df_wine['acidity'].min()
max_acidity=df_wine['acidity'].max()

print(f'El valor minimo del cuerpo es {min_body} y el maximo {max_body}')
print(f'El valor minimo de la acidez es {min_acidity} y el maximo {max_acidity}')
# Out:
# El valor minimo del cuerpo es 2.0 y el maximo 5.0
# El valor minimo de la acidez es 1.0 y el maximo 3.0

# %%
mix_body=2.0
max_body=5.0
min_acidity=1.0
max_acidity=3.0

df_wine['body_score'] = 1 + (df_wine['body'] - min_body) * (9 / (max_body - min_body))
df_wine['acidity_score'] = 1 + (df_wine['acidity'] - min_acidity) * (9 / (max_acidity - min_acidity))

df_wine.drop(['body', 'acidity'], axis=1, inplace=True)

# %%
df_wine.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body_score  acidity_score
# 0              Toro  995.00              Toro Red        10.0           10.0
# 1    Vino de Espana  313.50           Tempranillo         7.0            5.5
# 2  Ribera del Duero  324.95  Ribera Del Duero Red        10.0           10.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red        10.0           10.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red        10.0           10.0

# %% [markdown]
# ## 5. **Filtrado y búsquedas**
#  * Localiza los vinos de Málaga.

# %%
df_malaga=df_wine[df_wine['region']=='Malaga']
df_malaga
# Out:
#                winery            wine  year  rating  num_reviews country  \
# 340   Telmo Rodriguez     Molino Real  2016     4.6           28  España
# 739        Ramos-Paul           Tinto  2006     4.4          443  España
# 967     Jorge Ordonez  No. 2 Victoria  2018     4.4           64  España
# 1343    Jorge Ordonez  No. 2 Victoria  2017     4.3          232  España
# 1717  Telmo Rodriguez     Molino Real  2015     4.3           38  España
#
#       region  price   type  body_score  acidity_score  calidad_precio  calidad
# 340   Malaga  41.69    NaN         NaN            NaN        9.063043     True
# 739   Malaga  34.00  Tinto         NaN            NaN        7.727273    False
# 967   Malaga  15.90    NaN         NaN            NaN        3.613636    False
# 1343  Malaga  21.40    NaN         NaN            NaN        4.976744    False
# 1717  Malaga  53.30    NaN         NaN            NaN       12.395349    False

# %% [markdown]
# ## 6. **Calidad-precio**
# * Crea una columna que sea el precio dividido por el rating del vino.

# %%
df_wine['calidad_precio'] = df_wine['price']/df_wine['rating']
df_wine.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body_score  acidity_score  \
# 0              Toro  995.00              Toro Red        10.0           10.0
# 1    Vino de Espana  313.50           Tempranillo         7.0            5.5
# 2  Ribera del Duero  324.95  Ribera Del Duero Red        10.0           10.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red        10.0           10.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red        10.0           10.0
#
#    calidad_precio
# 0      203.061224
# 1       63.979592
# 2       67.697917
# 3      144.366667
# 4      162.095833

# %% [markdown]
# ## 7. **Reemplazo de caracteres**
# * Reemplaza la letra n por la letra ñ en la columna Country.
# * ¿Crees que es necesario hacerlo en alguna otra columna? Razona tu respuesta.

# %%
df_wine['country'] = df_wine ['country'].str.replace('n','ñ')
df_wine.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  España
# 1         Artadi  Vina El Pison  2018     4.9           31  España
# 2   Vega Sicilia          Unico  2009     4.8         1793  España
# 3   Vega Sicilia          Unico  1999     4.8         1705  España
# 4   Vega Sicilia          Unico  1996     4.8         1309  España
#
#              region   price                  type  body_score  acidity_score  \
# 0              Toro  995.00              Toro Red        10.0           10.0
# 1    Vino de Espana  313.50           Tempranillo         7.0            5.5
# 2  Ribera del Duero  324.95  Ribera Del Duero Red        10.0           10.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red        10.0           10.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red        10.0           10.0
#
#    calidad_precio
# 0      203.061224
# 1       63.979592
# 2       67.697917
# 3      144.366667
# 4      162.095833

# %% [markdown]
# ## 8. **Reemplazo de valores de texto**
# * Reemplaza Red por Tinto en todo el DataFrame.
# * Ahora localiza los vinos tintos dentro del DataFrame.

# %%
df_wine=df_wine.replace('Red', 'Tinto')
df_wine
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body_score  \
# 0     España              Toro  995.00              Toro Red        10.0
# 1     España    Vino de Espana  313.50           Tempranillo         7.0
# 2     España  Ribera del Duero  324.95  Ribera Del Duero Red        10.0
# 3     España  Ribera del Duero  692.96  Ribera Del Duero Red        10.0
# 4     España  Ribera del Duero  778.06  Ribera Del Duero Red        10.0
# ...      ...               ...     ...                   ...         ...
# 7495  España             Rioja   19.98             Rioja Red         7.0
# 7496  España          Priorato   16.76           Priorat Red         7.0
# 7497  España      El Terrerazo   24.45                 Tinto         7.0
# 7498  España  Ribera del Duero   64.50  Ribera Del Duero Red        10.0
# 7499  España  Ribera del Duero   31.63  Ribera Del Duero Red        10.0
#
#       acidity_score  calidad_precio
# 0              10.0      203.061224
# 1               5.5       63.979592
# 2              10.0       67.697917
# 3              10.0      144.366667
# 4              10.0      162.095833
# ...             ...             ...
# 7495           10.0        4.757143
# 7496           10.0        3.990476
# 7497           10.0        5.821429
# 7498           10.0       15.357143
# 7499           10.0        7.530952
#
# [7500 rows x 12 columns]

# %%
tintos = df_wine[df_wine['type']=='Tinto']
tintos
# Out:
#                             winery                          wine  year  \
# 18                 Bodegas El Nido                       El Nido  2018
# 43    Descendientes de J. Palacios  La Faraona Bierzo (Corullon)  2017
# 70                 Bodegas El Nido                       El Nido  2014
# 71                 Bodegas El Nido                       El Nido  2013
# 74                 Bodegas El Nido                       El Nido  2016
# ...                            ...                           ...   ...
# 7453                     Clos Pons                        Roc Nu  2011
# 7472                   Mustiguillo               Finca Terrerazo  2017
# 7477               Enrique Mendoza                    Santa Rosa  2017
# 7478                     Clos Pons                        Roc Nu  2011
# 7497                   Mustiguillo               Finca Terrerazo  2017
#
#       rating  num_reviews country             region        price   type  \
# 18       4.8          217  España            Jumilla   195.627380  Tinto
# 43       4.8           26  España             Bierzo  1098.900000  Tinto
# 70       4.7          511  España            Jumilla   154.900000  Tinto
# 71       4.7          476  España            Jumilla   145.000000  Tinto
# 74       4.7          393  España            Jumilla   371.780098  Tinto
# ...      ...          ...     ...                ...          ...    ...
# 7453     4.2          420  España  Costers del Segre    23.950000  Tinto
# 7472     4.2          390  España       El Terrerazo    24.450000  Tinto
# 7477     4.2          420  España           Alicante    18.900000  Tinto
# 7478     4.2          420  España  Costers del Segre    23.950000  Tinto
# 7497     4.2          390  España       El Terrerazo    24.450000  Tinto
#
#       body_score  acidity_score  calidad_precio
# 18           7.0           10.0       40.755704
# 43           7.0           10.0      228.937500
# 70           7.0           10.0       32.957447
# 71           7.0           10.0       30.851064
# 74           7.0           10.0       79.102148
# ...          ...            ...             ...
# 7453         7.0           10.0        5.702381
# 7472         7.0           10.0        5.821429
# 7477         7.0           10.0        4.500000
# 7478         7.0           10.0        5.702381
# 7497         7.0           10.0        5.821429
#
# [864 rows x 12 columns]

# %% [markdown]
#  ## 9. **Detección de columnas redundantes**
# * ¿Crees que hay columnas redundantes en el DataFrame? Si es así, indícalas.

# %% [markdown]
# No hay columnas que sean redundantes, sin embargo, columnas como `calidad_precio` son derivadas de otras (`price` y `rating`), por lo cual, dependiendo del objetivo del análisis, podrían considerarse redundantes o prescindibles.

# %%
df_wine.columns
# Out:
# Index(['winery', 'wine', 'year', 'rating', 'num_reviews', 'country', 'region',
#        'price', 'type', 'body_score', 'acidity_score', 'calidad_precio'],
#       dtype='object')

# %% [markdown]
#  ## 10. **Clasificación simple**
# * Genera una columna que sea True cuando un vino tenga más de un 4,5 de rating, y False en caso contrario.

# %%
df_wine['calidad'] = df_wine['rating']>4.5
df_wine
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body_score  \
# 0     España              Toro  995.00              Toro Red        10.0
# 1     España    Vino de Espana  313.50           Tempranillo         7.0
# 2     España  Ribera del Duero  324.95  Ribera Del Duero Red        10.0
# 3     España  Ribera del Duero  692.96  Ribera Del Duero Red        10.0
# 4     España  Ribera del Duero  778.06  Ribera Del Duero Red        10.0
# ...      ...               ...     ...                   ...         ...
# 7495  España             Rioja   19.98             Rioja Red         7.0
# 7496  España          Priorato   16.76           Priorat Red         7.0
# 7497  España      El Terrerazo   24.45                 Tinto         7.0
# 7498  España  Ribera del Duero   64.50  Ribera Del Duero Red        10.0
# 7499  España  Ribera del Duero   31.63  Ribera Del Duero Red        10.0
#
#       acidity_score  calidad_precio  calidad
# 0              10.0      203.061224     True
# 1               5.5       63.979592     True
# 2              10.0       67.697917     True
# 3              10.0      144.366667     True
# 4              10.0      162.095833     True
# ...             ...             ...      ...
# 7495           10.0        4.757143    False
# 7496           10.0        3.990476    False
# 7497           10.0        5.821429    False
# 7498           10.0       15.357143    False
# 7499           10.0        7.530952    False
#
# [7500 rows x 13 columns]
